# %% [markdown]
# <a href="https://colab.research.google.com/github/WillianReinaG/pregunta-smart-icesi/blob/main/taller2unitrabajo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: importar panda as pd

import pandas as pd

# %%
# prompt: Leer el conjunto de datos ubicado en /student_performance.csv proporcionada y asignarlo a la variable "df"

import pandas as pd

df = pd.read_csv('/student_performance.csv')

# %%
# Mostrar las primeras 5 filas del dataset utilizando el método dataframe.head()
print("Las primeras 5 filas del data frame:")
df.head(5)
# Out:
# Las primeras 5 filas del data frame:
#    StudentID     Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1     John    Male              85                 15
# 1          2    Sarah  Female              90                 20
# 2          3     Alex    Male              78                 10
# 3          4  Michael    Male              92                 25
# 4          5     Emma  Female              88                 18
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# 2             65                          0             Low          68
# 3             90                          3            High          92
# 4             82                          2          Medium          85

# %%
#Comprobar el tipo de datos del data frame "df" por medio de .dtypes
print(df.dtypes)
# Out:
# StudentID                     int64
# Name                         object
# Gender                       object
# AttendanceRate                int64
# StudyHoursPerWeek             int64
# PreviousGrade                 int64
# ExtracurricularActivities     int64
# ParentalSupport              object
# FinalGrade                    int64
# dtype: object

# %%
#astype(). Convirtamos los tipos de datos al formato apropiado:
# PARA NUESTRO EJERCICIO NO SE REQUIEREN MODIFICAR EL TIPO DE DATOS YA QUE ES CORRECTO
#df[["NOMBRE1", "NOMBRE2"]] = df[["NOMBRE1", "NOMBRE2"]].astype("float")
#df[["NOMBRE3", "NOMBRE4"]] = df[["NOMBRE3", "NOMBRE4"]].astype("int")
# POR ESA RAZON CONTINUAREMOS REVISANDO VALORES NULOS
# Verificar valores nulos
valores_nulos = df.isnull().sum()
print(valores_nulos)
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# dtype: int64

# %%
# Obtener el resumen estadístico de las columnas de tipo numérico
df.describe()
# Out:
#        StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count   10.00000       10.000000          10.000000      10.000000
# mean     5.50000       85.600000          17.700000      78.100000
# std      3.02765        7.441625           6.848357      10.170218
# min      1.00000       70.000000           8.000000      60.000000
# 25%      3.25000       82.750000          12.750000      71.750000
# 50%      5.50000       86.500000          17.500000      80.000000
# 75%      7.75000       90.750000          21.500000      85.750000
# max     10.00000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities  FinalGrade
# count                  10.000000   10.000000
# mean                    1.500000   80.200000
# std                     1.080123   10.097304
# min                     0.000000   62.000000
# 25%                     1.000000   73.500000
# 50%                     1.500000   82.500000
# ...

# %%
# Obtener el resumen estadístico de todas las columnas de "df"
#todas las columnas incluyendo aquellas de tipo object?
df.describe(include = "all")
# Out:
#         StudentID  Name Gender  AttendanceRate  StudyHoursPerWeek  \
# count    10.00000    10     10       10.000000          10.000000
# unique        NaN    10      2             NaN                NaN
# top           NaN  John   Male             NaN                NaN
# freq          NaN     1      5             NaN                NaN
# mean      5.50000   NaN    NaN       85.600000          17.700000
# std       3.02765   NaN    NaN        7.441625           6.848357
# min       1.00000   NaN    NaN       70.000000           8.000000
# 25%       3.25000   NaN    NaN       82.750000          12.750000
# 50%       5.50000   NaN    NaN       86.500000          17.500000
# 75%       7.75000   NaN    NaN       90.750000          21.500000
# max      10.00000   NaN    NaN       95.000000          30.000000
#
#         PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# count       10.000000                  10.000000              10   10.000000
# ...

# %%
# Obtener el resumen estadístico de las columnas 'longitud' y 'relacion-compresion'.
df [["AttendanceRate" , "StudyHoursPerWeek"]].describe()
# Out:
#        AttendanceRate  StudyHoursPerWeek
# count       10.000000          10.000000
# mean        85.600000          17.700000
# std          7.441625           6.848357
# min         70.000000           8.000000
# 25%         82.750000          12.750000
# 50%         86.500000          17.500000
# 75%         90.750000          21.500000
# max         95.000000          30.000000

# %%
import matplotlib.pyplot as plt
# Assuming 'df' is the DataFrame you want to plot, replace '_df_2' with 'df'
df.plot(kind='scatter', x='AttendanceRate', y='StudyHoursPerWeek', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show() # Add this line to display the plot

# %%
# Ver la información de "df"
# dataframe.info. Èste proporciona un resumen consiso de su data frame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10 non-null     int64
#  1   Name                       10 non-null     object
#  2   Gender                     10 non-null     object
#  3   AttendanceRate             10 non-null     int64
#  4   StudyHoursPerWeek          10 non-null     int64
#  5   PreviousGrade              10 non-null     int64
#  6   ExtracurricularActivities  10 non-null     int64
#  7   ParentalSupport            10 non-null     object
#  8   FinalGrade                 10 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 848.0+ bytes

# %%
# prompt: importar libreria altair

import altair as alt

# %%
# prompt: importar libreria altair

import altair as alt

# Gender vs FinalGrade diagrama de dispersion con altair
alt.Chart(df).mark_circle().encode(x='Gender',y='FinalGrade')
# Out:
# alt.Chart(...)

# %%
# Intanciar un objeto Chart con el dataframe df como parámetro
base = alt.Chart(df)

# Llamar el método mark_circle() para especificar que va a trazar un diagrama de dispersión (scatter plot)
chart = base.mark_circle()

# Especificar el nombre de las columnas:
chart.encode(x='Gender',y='FinalGrade')
# Out:
# alt.Chart(...)

# %%
# Gender vs FinalGrade diagrama de dispersion con altair
alt.Chart(df).mark_circle().encode(
    x='Gender',
    y='FinalGrade',
    color='ExtracurricularActivities:N'  # Explicitly specify nominal (N) data type for color
)
# Out:
# alt.Chart(...)

# %%
# se crea esta grafica para identificar alunmo con mas horas semanal y cuan serca esta de grade final
alt.Chart(df).mark_circle()\
   .encode(x='Name', y='FinalGrade', color='StudyHoursPerWeek', \
           tooltip=['ExtracurricularActivities','Gender','AttendanceRate',\
                    'ExtracurricularActivities','PreviousGrade']).interactive()
# Out:
# alt.Chart(...)

# %%
# prompt: Name vs FinalGrade por color de Gender diagrama de dispersion con altair y tooltip

alt.Chart(df).mark_circle().encode(
    x='Name',
    y='FinalGrade',
    color='Gender',
    tooltip=['Gender']
).interactive()
# Out:
# alt.Chart(...)

# %%
# histograma El eje x de un histograma, muestra los posibles valores de la columna y el
# eje y traza el número de instancias que tienen cada determinado valor.
alt.Chart(df).mark_bar()\
   .encode(alt.X("FinalGrade:Q", bin=True), \
           y='count()')
# Out:
# alt.Chart(...)

# %%
# prompt: con alt.bin Grafique el histograma para el atributo precio agrupando los precios en rangos de 10 y detallando el color del Gender.
# IA
alt.Chart(df).mark_bar().encode(
    alt.X("FinalGrade:Q", bin=alt.Bin(step=10)),
    y='count()',
    color='Gender'
)
# Out:
# alt.Chart(...)

# %%
#Diagramas de caja (Boxplots)
##distribución de una variable en función de sus cuartiles
alt.Chart(df).mark_boxplot().encode(x='ExtracurricularActivities:O', y='FinalGrade:Q')
# Out:
# alt.Chart(...)

# %%
#Diagramas de caja (Boxplots)
##distribución de una variable en función de sus cuartiles
alt.Chart(df).mark_boxplot().encode(x='Gender:O', y='FinalGrade:Q')
# Out:
# alt.Chart(...)

# %%
#Mapa de calor (Heatmap)
# Obtener la correlación entre variables por medio del coeficiente de correlación de Pearson
# coeficiente de correlación de Pearson. Otros dos métodos conocidos son el
# coeficiente de correlación de rango de Kendall y el coeficiente de correlación de Spearman.
correlation = df.corr(method='pearson',numeric_only=True).reset_index().melt('index')
correlation.columns = ['variable1', 'variable2', 'indice-correlation']

correlation.head()
# Out:
#                    variable1  variable2  indice-correlation
# 0                  StudentID  StudentID            1.000000
# 1             AttendanceRate  StudentID           -0.064110
# 2          StudyHoursPerWeek  StudentID            0.008038
# 3              PreviousGrade  StudentID           -0.102841
# 4  ExtracurricularActivities  StudentID            0.220847

# %%
# Grafica del mapa de calor
chart = alt.Chart(correlation).mark_rect().encode(
    x=alt.X('variable1', title=None),
    y=alt.Y('variable2', title=None),
    # El color de cada casilla dependerá del índice de correlación hallado
    color=alt.Color('indice-correlation'),
).properties(
    # Establecemos el tamaño del gráfico
    width=alt.Step(40),
    height=alt.Step(40)
)

# Personalizamos el tamaño del texto de las casillas internas
chart += chart.mark_text(size=10).encode(
    # Establecemos el formato de la barra de temperatura
    text=alt.Text('indice-correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)
# Desplegamos el gráfico
chart
# Out:
# alt.LayerChart(...)

# %%
# prompt: Genere el mapa de calor utilizando el coeficiente de correlación de Spearman. Establezca el tamaño del gráfico en 60 x 60 y un tamaño de letra de 20 para las casillas

# Obtener la correlación entre variables por medio del coeficiente de correlación de Spearman
correlation = df.corr(method='spearman',numeric_only=True).reset_index().melt('index')
correlation.columns = ['variable1', 'variable2', 'indice-correlation']

# Grafica del mapa de calor
chart = alt.Chart(correlation).mark_rect().encode(
    x=alt.X('variable1', title=None),
    y=alt.Y('variable2', title=None),
    # El color de cada casilla dependerá del índice de correlación hallado
    color=alt.Color('indice-correlation'),
).properties(
    # Establecemos el tamaño del gráfico
    width=alt.Step(60),  # Changed to 60
    height=alt.Step(60)  # Changed to 60
)

# Personalizamos el tamaño del texto de las casillas internas
chart += chart.mark_text(size=20).encode(  # Changed to 20
    # Establecemos el formato de la barra de temperatura
    text=alt.Text('indice-correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)

# Desplegamos el gráfico
chart
# Out:
# alt.LayerChart(...)
